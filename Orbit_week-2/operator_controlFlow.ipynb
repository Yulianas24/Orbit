# %%
for i in range(1, 101):
  if(i%3 == 0 and i%5 == 0):
    print("Joko Widodo")
  elif(i % 3==0):
    print("Joko")
  elif(i%5 == 0):
    print("Widodo")
  else:
    print(i)
# Out:
# 1
# 2
# Joko
# 4
# Widodo
# Joko
# 7
# 8
# Joko
# Widodo
# 11
# Joko
# 13
# 14
# Joko Widodo
# 16
# 17
# Joko
# 19
# Widodo
# Joko
# 22
# 23
# Joko
# Widodo
# 26
# Joko
# 28
# 29
# Joko Widodo
# 31
# 32
# Joko
# 34
# Widodo
# Joko
# 37
# 38
# Joko
# Widodo
# 41
# Joko
# 43
# 44
# Joko Widodo
# 46
# 47
# Joko
# 49
# Widodo
# Joko
# 52
# 53
# Joko
# Widodo
# 56
# Joko
# 58
# 59
# Joko Widodo
# 61
# 62
# Joko
# 64
# Widodo
# Joko
# 67
# 68
# Joko
# Widodo
# 71
# Joko
# 73
# 74
# Joko Widodo
# 76
# 77
# Joko
# 79
# Widodo
# Joko
# 82
# 83
# Joko
# Widodo
# 86
# Joko
# 88
# 89
# Joko Widodo
# 91
# 92
# Joko
# 94
# Widodo
# Joko
# 97
# 98
# Joko
# Widodo

# %%
for i in range(11):
  if(i==0):
    print("  "*10,"*")
  elif(10>i>=1):
    print('  '*(10-i)+"*"+'  '*(i*2)+"*")
  else:
    print("*   "*i)
# Out:
#                      *
#                   *    *
#                 *        *
#               *            *
#             *                *
#           *                    *
#         *                        *
#       *                            *
#     *                                *
#   *                                    *
# *   *   *   *   *   *   *   *   *   *
